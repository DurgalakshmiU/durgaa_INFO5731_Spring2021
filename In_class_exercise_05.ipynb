# %% [markdown]
# <a href="https://colab.research.google.com/github/DurgalakshmiU/durgaa_INFO5731_Spring2021/blob/main/In_class_exercise_05.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## The fifth In-class-exercise (2/23/2021, 20 points in total)

# %% [markdown]
# In exercise-03, I asked you to collected 500 textual data based on your own information needs (If you didn't collect the textual data, you should recollect for this exercise). Now we need to think about how to represent the textual data for text classification. In this exercise, you are required to select 10 types of features (10 types of features but absolutely more than 10 features) in the followings feature list, then represent the 500 texts with these features. The output should be in the following format:
# ![image.png](attachment:image.png)
#
# The feature list:
#
# * (1) tf-idf features
# * (2) POS-tag features: number of adjective, adverb, auxiliary, punctuation, complementizer, coordinating conjunction, subordinating conjunction, determiner, interjection, noun, possessor, preposition, pronoun, quantifier, verb, and other. (select some of them if you use pos-tag features)
# * (3) Linguistic features:
#   * number of right-branching nodes across all constituent types
#   * number of right-branching nodes for NPs only
#   * number of left-branching nodes across all constituent types
#   * number of left-branching nodes for NPs only
#   * number of premodifiers across all constituent types
#   * number of premodifiers within NPs only
#   * number of postmodifiers across all constituent types
#   * number of postmodifiers within NPs only
#   * branching index across all constituent types, i.e. the number of right-branching nodes minus number of left-branching nodes
#   * branching index for NPs only
#   * branching weight index: number of tokens covered by right-branching nodes minus number of tokens covered by left-branching nodes across all categories
#   * branching weight index for NPs only
#   * modification index, i.e. the number of premodifiers minus the number of postmodifiers across all categories
#   * modification index for NPs only
#   * modification weight index: length in tokens of all premodifiers minus length in tokens of all postmodifiers across all categories
#   * modification weight index for NPs only
#   * coordination balance, i.e. the maximal length difference in coordinated constituents
#
#   * density (density can be calculated using the ratio of folowing function words to content words) of determiners/quantifiers
#   * density of pronouns
#   * density of prepositions
#   * density of punctuation marks, specifically commas and semicolons
#   * density of auxiliary verbs
#   * density of conjunctions
#   * density of different pronoun types: Wh, 1st, 2nd, and 3rd person pronouns
#
#   * maximal and average NP length
#   * maximal and average AJP length
#   * maximal and average PP length
#   * maximal and average AVP length
#   * sentence length
#
# * Other features in your mind (ie., pre-defined patterns)

# %%
import requests
from bs4 import BeautifulSoup as bs
import pandas as pd
url='https://www.imdb.com/list/ls050782187/?sort=list_order,asc&st_dt=&mode=detail&page='
l1=[]

#for getting texts from pages
for page in range(1,6):         
    req=requests.get(url + str(page))
    soup=bs(req.content,'html.parser')
    result=soup.find_all('h3',{'class':'lister-item-header'})
    for i in result:
      l1.append(i.text)
      #print(i.text)           #collection of 500 texts
#Collected Texts in csv file
import re
df=pd.DataFrame()
df['Movie name']=l1
df = df.replace('\n','', regex=True)
df.to_csv(r'/content/movietop.csv',index=True) 
df
# Out:
#                                             Movie name
# 0                                1.The Godfather(1972)
# 1                     2.The Silence of the Lambs(1991)
# 2    3.Star Wars: Episode V - The Empire Strikes Ba...
# 3                     4.The Shawshank Redemption(1994)
# 4                                  5.The Shining(1980)
# ..                                                 ...
# 495                       496.Me, Myself & Irene(2000)
# 496                   497.The Darjeeling Limited(2007)
# 497                                     498.Fear(1996)
# 498                            499.Planet Terror(2007)
# 499                              500.The Descent(2005)
#
# [500 rows x 1 columns]

# %%
#cleaning
df = pd.read_csv('movietop.csv')
df.to_csv("movietop.csv", index=False)
df['cleansentence'] = df['Movie name'].apply(lambda a: " ".join(a.lower() for a in a.split()))
df['cleansentence'].head()  #lower casing
df['cleansentence'] =df['cleansentence'] .str.replace('[^\w\s]','')
df['cleansentence'] .head()  # special char and punctuation removal
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
stop = stopwords.words('english')
df['cleansentence']= df['cleansentence'].apply(lambda a: " ".join(a for a in a.split() if a not in stop))
df['cleansentence'].head()  #stopwords removal
df['cleansentence'] = df['cleansentence'].str.replace("[0-9]", " ")
df['cleansentence'].head()      #Numbers removal
from nltk.stem import PorterStemmer
st = PorterStemmer()    #stemming
df['cleansentence'][:6].apply(lambda a: " ".join([st.stem(word) for word in a.split()]))
nltk.download('wordnet')
from textblob import Word
df['cleansentence'] = df['cleansentence'].apply(lambda a: " ".join([Word(word).lemmatize() for word in a.split()]))
df['cleansentence'].head()   #Lemmatization
df.to_csv('movietop.csv')     #Adding cleaned sentence column to csv file
df                  #cleaned sentence
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
#      Unnamed: 0  ...                          cleansentence
# 0             0  ...                          the godfather
# 1             1  ...                       the silence lamb
# 2             2  ...  star war episode v empire strike back
# 3             3  ...               the shawshank redemption
# 4             4  ...                            the shining
# ..          ...  ...                                    ...
# 495         495  ...                               me irene
# 496         496  ...                 the darjeeling limited
# 497         497  ...                                   fear
# 498         498  ...                          planet terror
# 499         499  ...                            the descent
#
# [500 rows x 4 columns]

# %%
#tf-idf features
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
import numpy as np
import pandas as pd
import re
sentences = list()
df = pd.read_csv('movietop.csv')
df['Movie name']= df['Movie name'].str.replace('\d+', '')
df['Movie name'] =df['Movie name'] .str.replace('[^\w\s]','')
df.to_csv("movietop1.csv", index=False)
with open("movietop1.csv") as file:
    for line in file:
        for l in re.split(r"\.\s|\?\s|\!\s|\n",line):
            if l:
                sentences.append(l)
cvec = CountVectorizer(stop_words='english', min_df=3, max_df=0.5, ngram_range=(1,2))
s = cvec.fit_transform(sentences)
transformer = TfidfTransformer()
transformed_weights = transformer.fit_transform(s)
w = np.asarray(transformed_weights.mean(axis=0)).ravel().tolist()
weights_df = pd.DataFrame({'term': cvec.get_feature_names(), 'Result of tf-idf': w})
a=pd.DataFrame()
a=weights_df.sort_values(by='Result of tf-idf', ascending=False)
a.head(500)
# Out:
#                   term  Result of tf-idf
# 32                 man          0.026411
# 9                 dead          0.012355
# 0             american          0.009980
# 7                 dark          0.009980
# 17                good          0.009980
# 33                 men          0.007984
# 31                love          0.007984
# 26                life          0.007984
# 6                 city          0.007372
# 15                game          0.007372
# 24                king          0.007125
# 8                  day          0.006853
# 25                  la          0.006853
# 20              hobbit          0.005988
# 47            sunshine          0.005988
# 42                 saw          0.005988
# 3                blood          0.005988
# 4               bourne          0.005988
# 1                  big          0.005988
# 30                lost          0.005988
# 19               harry          0.005988
# 13                fear          0.005791
# 23                kill          0.005431
# 43                 spy          0.005431
# 16           godfather          0.005403
# 18                hard          0.005363
# 44                star          0.005345
# 12             episode          0.005345
# 14              future          0.005206
# 2                black          0.005174
# 5            caribbean          0.005112
# 27                lord          0.004944
# 21                  ii          0.004320
# 48                 war          0.003964
# 10                 die          0.003501
# 11            die hard          0.003501
# 22          impossible          0.003457
# 35  mission impossible          0.003457
# 34             mission          0.003457
# 40                ring          0.002822
# 50                wars          0.002673
# 49         war episode          0.002673
# 46           star wars          0.002673
# 45            star war          0.002673
# 51        wars episode          0.002673
# 39   pirates caribbean          0.002556
# 38             pirates          0.002556
# 37    pirate caribbean          0.002556
# 36              pirate          0.002556
# 41               rings          0.001814
# 29          lord rings          0.001814
# 28           lord ring          0.001814

# %%
import nltk
nltk.download('punkt')
from nltk import word_tokenize, pos_tag, pos_tag_sents
nltk.download('averaged_perceptron_tagger')
# !pip install counter
from collections import Counter
import pandas as pd
nltk.download('universal_tagset')
t= df['cleansentence'].tolist()
map(word_tokenize, t)
df['cleansentence'] = df['cleansentence'].astype(str)
df['cleansentence'].apply(word_tokenize)
p=pd.DataFrame()
pos_tag=[]
Count=0
v=0
for z in df['cleansentence']:
  token=nltk.word_tokenize(z)
  pos_tag.append(nltk.pos_tag(token,tagset='universal'))
  Count=(dict(nltk.FreqDist(tag for (word, tag) in pos_tag[v])))
  Count['Texts']=z
  p=p.append(Count,ignore_index=True)
  #print(p)
  v=v+1
df1=pd.DataFrame
df1=p.fillna(0)
df1['sentence length']=df['cleansentence'].apply(len)
df1
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# Requirement already satisfied: counter in /usr/local/lib/python3.7/dist-packages (1.0.0)
# [nltk_data] Downloading package universal_tagset to /root/nltk_data...
# [nltk_data]   Package universal_tagset is already up-to-date!
#      DET  NOUN  ... PRON  sentence length
# 0    1.0   1.0  ...  0.0               13
# 1    1.0   2.0  ...  0.0               16
# 2    0.0   5.0  ...  0.0               37
# 3    1.0   2.0  ...  0.0               24
# 4    1.0   1.0  ...  0.0               11
# ..   ...   ...  ...  ...              ...
# 495  0.0   1.0  ...  1.0                8
# 496  1.0   1.0  ...  0.0               22
# 497  0.0   1.0  ...  0.0                4
# 498  0.0   2.0  ...  0.0               13
# 499  1.0   1.0  ...  0.0               11
#
# [500 rows x 12 columns]

# %%
#Dependancy parsing
import spacy
nlp=spacy.load('en_core_web_sm')
li=[]
for i in range(0,500):
 text1=(df['cleansentence'][i])
 li.append(text1)
sentence = " ".join(li)
for token in nlp(sentence):
 print(token.text,'=>',token.dep_,'=>',token.head.text)
# Out:
# the => det => godfather
# godfather => nsubj => strike
# the => det => war
# silence => compound => war
# lamb => compound => star
# star => compound => war
# war => nsubj => episode
# episode => relcl => godfather
# v => compound => strike
# empire => compound => strike
# strike => ROOT => strike
# back => advmod => strike
# the => det => redemption
# shawshank => compound => redemption
# redemption => dobj => strike
# the => det => casablanca
# shining => amod => casablanca
# casablanca => nsubj => flew
# one => nummod => casablanca
# flew => relcl => redemption
# cuckoo => compound => raider
# nest => compound => raider
# indiana => compound => jones
# jones => compound => raider
# raider => nsubj => lost
# lost => ROOT => lost
# ark => prep => lost
# the => det => ring
# lord => compound => ring
# ring => nsubj => return
# return => compound => war
# king => compound => war
# star => compound => war
# war => nsubj => episode
# episode => ROOT => episode
# iv => nmod => hope
# new => amod => hope
# hope => ROOT => hope
# the => det => knight
# dark => amod => knight
# knight => ROOT => knight
# the => det => godfather
# godfather => compound => part
# part => ROOT => part
# ii => nummod => inception
# alien => compound => list
# schindlers => compound => list
# list => compound => inception
# inception => ROOT => inception
# the => det => lord
# lord => nsubj => ring
# ring => acl => inception
# fellowship => compound => ring
# ring => dobj => ring
# alien => ROOT => alien
# some => det => apocalypse
# like => intj => some
# hot => amod => blade
# blade => compound => runner
# runner => pobj => like
# seven => nummod => apocalypse
# apocalypse => intj => alien
# now => advmod => apocalypse
# angry => amod => men
# men => appos => apocalypse
# the => det => lord
# lord => nsubj => ring
# ring => relcl => men
# two => nummod => tower
# tower => dobj => ring
# terminator => compound => day
# judgment => compound => day
# day => compound => war
# star => compound => war
# war => nsubj => episode
# episode => ROOT => episode
# vi => compound => return
# return => compound => jedi
# jedi => nsubj => die
# die => ccomp => episode
# hard => amod => fiction
# gejaagd => amod => fiction
# door => nmod => wind
# de => nmod => wind
# wind => compound => fiction
# taxi => compound => driver
# driver => compound => fiction
# pulp => compound => fiction
# fiction => dobj => die
# the => det => kwai
# bridge => compound => river
# river => compound => kwai
# kwai => ROOT => kwai
# the => det => king
# lion => compound => king
# king => compound => window
# north => nmod => window
# northwest => compound => window
# rear => amod => window
# window => appos => kwai
# léon => prep => kwai
# terug => nmod => toekomst
# naar => nmod => toekomst
# de => nmod => toekomst
# toekomst => pobj => léon
# citizen => compound => kane
# kane => compound => goodfellas
# goodfellas => compound => beauty
# memento => compound => beauty
# american => amod => beauty
# beauty => nsubj => get
# a => det => good
# good => amod => get
# get => ROOT => get
# forrest => compound => braveheart
# gump => compound => singin
# singin => compound => braveheart
# rain => compound => braveheart
# braveheart => nsubj => saving
# saving => ROOT => saving
# private => amod => man
# ryan => compound => man
# rain => compound => man
# man => dobj => saving
# the => det => king
# king => compound => speech
# speech => ROOT => speech
# een => compound => ruimte
# zwerftocht => nmod => ruimte
# de => nmod => ruimte
# ruimte => compound => bill
# kill => compound => bill
# bill => compound => avanti
# vol => compound => avanti
# avanti => ROOT => avanti
# the => det => time
# good => amod => time
# bad => amod => time
# ugly => amod => amélie
# amélie => nmod => time
# modern => amod => time
# time => nsubj => lost
# lost => ROOT => lost
# translation => nmod => jacket
# full => amod => metal
# metal => compound => jacket
# jacket => compound => dream
# requiem => compound => dream
# dream => compound => fight
# fight => compound => club
# club => dobj => lost
# no => det => country
# country => ROOT => country
# old => amod => men
# men => nsubj => django
# django => relcl => country
# unchained => amod => leben
# child => compound => men
# men => compound => leben
# ratatouille => compound => leben
# da => compound => leben
# leben => compound => anderen
# der => compound => anderen
# anderen => dobj => django
# the => det => v
# prestige => compound => v
# v => det => trainspotting
# vendetta => compound => chinatown
# chinatown => compound => cidade
# cidade => compound => avontuur
# de => nmod => deus
# deus => compound => avontuur
# avontuur => compound => millionaire
# op => compound => millionaire
# martinique => nmod => millionaire
# fargo => compound => life
# life => appos => martinique
# pi => compound => slumdog
# slumdog => compound => millionaire
# millionaire => nsubj => vertigo
# vertigo => amod => trainspotting
# trainspotting => ROOT => trainspotting
# interstellar => advmod => trainspotting
# the => det => thing
# thing => dobj => trainspotting
# the => det => man
# third => amod => man
# man => nsubj => leven
# monkey => compound => het
# het => appos => man
# leven => relcl => thing
# mooi => dobj => leven
# the => det => magnolia
# pianist => compound => magnolia
# magnolia => dative => leven
# the => det => knight
# dark => amod => knight
# knight => nsubj => rise
# rise => compound => force
# star => compound => war
# war => compound => episode
# episode => compound => force
# vii => compound => force
# force => appos => magnolia
# awakens => nmod => hobbit
# de => nmod => hobbit
# hobbit => nmod => van
# de => compound => van
# woestenij => compound => van
# van => nsubj => smaug
# smaug => ROOT => smaug
# mad => compound => max
# max => compound => fury
# fury => compound => year
# road => compound => year
# year => compound => jones
# slave => compound => jones
# indiana => compound => jones
# jones => dobj => smaug
# last => amod => crusade
# crusade => ROOT => crusade
# o => compound => brother
# brother => ROOT => brother
# art => compound => thou
# thou => appos => brother
# inglourious => amod => basterds
# basterds => ROOT => basterds
# the => det => district
# departed => amod => district
# a => det => district
# beautiful => amod => district
# mind => compound => district
# district => ROOT => district
# the => det => river
# piano => compound => river
# mystic => compound => river
# river => appos => district
# the => det => insider
# insider => appos => district
# la => advmod => confidential
# confidential => amod => heat
# heat => ROOT => heat
# the => det => suspect
# usual => amod => suspect
# suspect => ROOT => suspect
# cool => compound => hand
# hand => appos => suspect
# luke => amod => sunshine
# eternal => amod => sunshine
# sunshine => compound => city
# spotless => compound => mind
# mind => compound => city
# city => compound => light
# light => appos => suspect
# the => det => misery
# matrix => compound => misery
# sin => compound => city
# city => compound => misery
# misery => ROOT => misery
# what => nsubj => eating
# s => aux => eating
# eating => relcl => misery
# gilbert => compound => grape
# grape => compound => grail
# monty => compound => grail
# python => compound => grail
# holy => compound => grail
# grail => dobj => eating
# the => det => hunter
# deer => compound => hunter
# hunter => nsubj => scarface
# scarface => ROOT => scarface
# a => det => clockwork
# clockwork => compound => orange
# orange => ccomp => scarface
# the => det => man
# elephant => compound => man
# man => ROOT => man
# papillon => compound => hotel
# lawrence => nmod => hotel
# arabia => intj => lawrence
# de => nmod => verloren
# verloren => compound => hotel
# zoon => compound => hotel
# hotel => appos => man
# rwanda => compound => dance
# dance => appos => hotel
# wolf => compound => pirate
# pirate => compound => caribbean
# caribbean => nsubj => curse
# curse => compound => batman
# black => amod => batman
# pearl => compound => batman
# batman => nsubj => begin
# begin => ROOT => begin
# skyfall => xcomp => begin
# the => det => treasure
# treasure => dobj => skyfall
# sierra => compound => madre
# madre => npadvmod => begin
# the => det => untouchable
# untouchable => amod => dog
# the => det => show
# truman => compound => show
# show => compound => dog
# reservoir => compound => dog
# dog => ROOT => dog
# het => advmod => appartement
# appartement => ROOT => appartement
# the => det => happiness
# big => amod => sleep
# sleep => nmod => happiness
# amour => compound => ben
# mielensäpahoittaja => compound => ben
# ben => compound => happiness
# hur => compound => happiness
# happiness => dobj => appartement
# ½ => compound => louise
# thelma => compound => louise
# louise => appos => happiness
# der => compound => gran
# untergang => compound => gran
# rocky => compound => gran
# gran => ROOT => gran
# torino => nmod => maniak
# de => compound => maniak
# maniak => appos => gran
# wie => compound => bang
# bang => compound => woolf
# voor => compound => virginia
# virginia => compound => woolf
# woolf => ROOT => woolf
# the => det => zodiac
# exorcist => intj => the
# de => nmod => onverwachte
# uitroeier => nmod => onverwachte
# de => nmod => hobbit
# hobbit => nmod => onverwachte
# een => nmod => onverwachte
# onverwachte => nmod => kill
# real => amod => kill
# kill => amod => gladiator
# bill => compound => gladiator
# vol => compound => gladiator
# gladiator => compound => zodiac
# traffic => compound => zodiac
# zodiac => nsubj => haai
# the => det => avatar
# green => amod => mile
# mile => compound => avatar
# avatar => appos => zodiac
# halloween => compound => witte
# casino => compound => witte
# de => compound => witte
# zomer => compound => witte
# van => compound => witte
# de => compound => witte
# witte => appos => avatar
# haai => ROOT => haai
# once => advmod => upon
# upon => prep => haai
# time => pobj => upon
# west => advmod => notorious
# notorious => ROOT => notorious
# the => det => escape
# great => amod => escape
# escape => ROOT => escape
# the => det => proof
# nightmare => compound => proof
# christmas => compound => proof
# goldfinger => compound => proof
# death => compound => proof
# proof => dobj => escape
# argo => compound => milki
# milki => nsubj => being
# being => acl => proof
# john => nmod => malkovich
# malkovich => nmod => swan
# black => amod => swan
# swan => attr => being
# the => det => others
# others => nsubj => brokeback
# brokeback => relcl => swan
# mountain => compound => collateral
# collateral => dobj => brokeback
# jackie => compound => brown
# brown => compound => royale
# casino => compound => royale
# royale => compound => platoon
# platoon => ROOT => platoon
# the => det => line
# thin => amod => line
# red => amod => line
# line => ROOT => line
# the => det => fire
# hunger => compound => game
# game => compound => fire
# catching => compound => fire
# fire => appos => line
# the => det => part
# godfather => compound => part
# part => appos => line
# iii => nmod => history
# american => amod => history
# history => appos => line
# x => intj => society
# dead => amod => society
# poet => compound => society
# society => ROOT => society
# the => det => visitori
# visitori => nsubj => hable
# hable => ROOT => hable
# con => compound => ella
# ella => dobj => hable
# män => compound => sideways
# som => compound => sideways
# hatar => compound => kvinnor
# kvinnor => compound => sideways
# da => compound => sideways
# boot => compound => sideways
# sideways => compound => takeni
# scent => compound => woman
# woman => compound => takeni
# deliverance => compound => takeni
# takeni => nsubj => ii
# back => advmod => takeni
# future => amod => part
# part => compound => ii
# ii => ROOT => ii
# the => det => man
# incredible => amod => man
# shrinking => amod => man
# man => dobj => ii
# the => det => shutter
# fugitive => amod => shutter
# shutter => nsubj => island
# island => appos => man
# the => det => lebowski
# big => amod => lebowski
# lebowski => dobj => island
# last => amod => tango
# tango => ROOT => tango
# paris => ROOT => paris
# the => det => ripley
# talented => amod => ripley
# mr => nmod => ripley
# ripley => nsubj => blood
# first => amod => blood
# blood => ROOT => blood
# the => det => baby
# ghost => compound => million
# writer => compound => million
# million => nummod => dollar
# dollar => compound => baby
# baby => ROOT => baby
# the => det => man
# man => nsubj => was
# was => ROOT => was
# nt => neg => was
# there => advmod => was
# the => det => wrestler
# wrestler => attr => was
# harry => nsubj => brown
# brown => relcl => wrestler
# the => det => identity
# bourne => compound => identity
# identity => nmod => folles
# la => compound => cage
# cage => compound => folles
# aux => compound => folles
# folles => dobj => brown
# there => advmod => folles
# blood => nsubj => elliot
# billy => advmod => elliot
# elliot => ROOT => elliot
# little => amod => sunshine
# miss => compound => sunshine
# sunshine => nsubj => leger
# de => nmod => hobbit
# hobbit => nmod => vijf
# de => compound => slag
# slag => compound => van
# van => compound => vijf
# vijf => appos => sunshine
# leger => ROOT => leger
# the => det => psycho
# hunger => compound => game
# game => compound => psycho
# psycho => dobj => leger
# et => nmod => kramer
# extraterrestrial => amod => kramer
# kramer => compound => kramer
# v => compound => kramer
# kramer => appos => psycho
# under => prep => psycho
# tuscan => amod => sun
# sun => compound => sith
# transamerica => compound => sith
# walle => nmod => sith
# dirty => compound => sith
# harry => compound => star
# star => compound => sith
# war => compound => sith
# episode => compound => sith
# iii => compound => sith
# revenge => compound => sith
# sith => pobj => under
# stand => ROOT => stand
# me => dative => stand
# a => det => nemo
# nightmare => compound => nemo
# elm => compound => street
# street => compound => nemo
# finding => compound => nemo
# nemo => dobj => stand
# in => prep => nemo
# mouth => compound => madness
# madness => pobj => in
# the => det => element
# fifth => amod => element
# element => dobj => stand
# the => det => sense
# sixth => amod => sense
# sense => nsubj => amores
# amores => compound => way
# perros => compound => way
# jurassic => compound => way
# park => compound => carlitos
# carlitos => compound => way
# way => ROOT => way
# army => compound => darkness
# darkness => ROOT => darkness
# a => det => fish
# fish => dobj => darkness
# called => acl => fish
# wanda => dobj => called
# good => amod => hunting
# hunting => oprd => called
# kat => compound => een
# op => compound => een
# een => nsubj => heet
# heet => ROOT => heet
# zinken => amod => recall
# dak => nmod => recall
# total => amod => recall
# recall => dobj => heet
# wo => aux => cang
# hu => nsubj => cang
# cang => ROOT => cang
# long => amod => cape
# fucking => amod => cape
# åmål => compound => gram
# gram => compound => cape
# cape => compound => fear
# fear => ROOT => fear
# inside => prep => fear
# man => compound => city
# sin => compound => city
# city => compound => dame
# dame => nsubj => kill
# kill => ROOT => kill
# for => prep => kill
# groundhog => compound => day
# day => pobj => for
# jfk => nmod => hawk
# black => amod => hawk
# hawk => dobj => kill
# down => prep => kill
# la => compound => educación
# mala => compound => educación
# educación => compound => man
# watchman => compound => jarige
# de => compound => jarige
# jarige => compound => man
# man => nsubj => die
# die => ROOT => die
# uit => compound => het
# het => compound => klom
# raam => compound => klom
# klom => nsubj => verdween
# en => advmod => verdween
# verdween => ccomp => die
# lilja => nmod => catch
# ever => advmod => catch
# mar => compound => catch
# adentroi => compound => catch
# catch => ROOT => catch
# can => aux => man
# man => ROOT => man
# moon => nmod => game
# alive => amod => game
# spy => compound => game
# game => dobj => man
# changeling => acl => game
# the => det => heist
# reader => compound => heist
# predator => compound => heist
# heist => dobj => changeling
# the => det => job
# bank => compound => job
# job => nmod => velvet
# blue => amod => velvet
# velvet => appos => heist
# high => amod => fidelity
# fidelity => ROOT => fidelity
# the => det => case
# curious => amod => case
# case => nsubj => choristes
# benjamin => compound => button
# button => appos => case
# the => det => patient
# english => amod => patient
# patient => appos => case
# the => det => wizard
# wizard => appos => case
# oz => prep => case
# the => det => story
# philadelphia => compound => story
# story => pobj => oz
# rio => compound => le
# bravo => compound => le
# le => compound => choristes
# choristes => ROOT => choristes
# lord => compound => stock
# war => compound => stock
# lock => compound => stock
# stock => dobj => choristes
# two => nummod => barrel
# smoking => compound => barrel
# barrel => appos => stock
# big => amod => braindead
# fish => compound => braindead
# braindead => npadvmod => choristes
# the => det => american
# quiet => amod => american
# american => nsubj => lost
# lost => amod => report
# highway => compound => minority
# minority => compound => report
# report => ROOT => report
# eastern => amod => ocean
# promise => compound => ocean
# ocean => nmod => love
# eleven => nummod => ocean
# water => compound => elephant
# elephant => compound => love
# love => dobj => report
# actually => advmod => report
# about => prep => report
# schmidt => compound => baby
# the => det => whisperer
# horse => compound => whisperer
# whisperer => compound => baby
# pan => compound => baby
# labyrinth => compound => baby
# corpse => compound => baby
# bride => compound => baby
# rosemary => compound => baby
# baby => pobj => about
# the => det => inc
# station => compound => inc
# agent => compound => inc
# monster => compound => inc
# inc => nsubj => martyr
# martyr => ROOT => martyr
# the => det => sting
# sting => ROOT => sting
# my => poss => lady
# fair => amod => lady
# lady => dobj => sting
# the => det => boy
# virgin => amod => boy
# suicide => compound => boy
# moulin => compound => rouge
# rouge => nmod => boy
# evil => amod => boy
# dead => amod => boy
# ii => nmod => boy
# biutiful => amod => boy
# frozeni => amod => wonder
# wonder => compound => boy
# boy => ROOT => boy
# leaving => acl => boy
# la => compound => vega
# vega => nmod => lincoln
# irréversible => amod => lincoln
# lincoln => compound => zero
# zero => nummod => thirty
# dark => amod => thirty
# thirty => dobj => leaving
# the => det => murderer
# abyss => compound => monster
# monster => compound => murderer
# ball => compound => murderer
# donnie => compound => brasco
# brasco => compound => murderer
# perfume => compound => story
# story => compound => murderer
# murderer => npadvmod => thirty
# la => prep => murderer
# piel => compound => que
# que => compound => prisoner
# habito => compound => prisoner
# prisoner => compound => diamond
# blood => compound => diamond
# diamond => pobj => la
# true => amod => romance
# romance => compound => boy
# boy => nsubj => cry
# do => aux => cry
# nt => neg => cry
# cry => ROOT => cry
# sophies => compound => choice
# choice => compound => line
# walk => compound => line
# line => dobj => cry
# the => det => carrie
# machinist => amod => carrie
# mammoth => amod => carrie
# carrie => nsubj => ai
# ai => ROOT => ai
# artificial => amod => hors
# intelligence => compound => hors
# hors => dobj => ai
# de => compound => prix
# prix => compound => misérables
# le => compound => misérables
# misérables => ROOT => misérables
# it => nsubj => complicated
# complicated => ccomp => misérables
# chocolat => advmod => complicated
# a => det => mulholland
# history => compound => violence
# violence => compound => mulholland
# mulholland => nsubj => drive
# drive => ROOT => drive
# raging => amod => bull
# bull => dobj => drive
# the => det => crow
# crow => ROOT => crow
# the => det => darko
# bridge => compound => county
# madison => compound => county
# county => compound => darko
# donnie => compound => darko
# darko => dobj => crow
# the => det => rule
# cider => compound => house
# house => compound => rule
# rule => ROOT => rule
# spartacus => compound => lethal
# lethal => amod => weapon
# weapon => ROOT => weapon
# mad => compound => max
# max => ROOT => max
# the => det => brother
# blue => amod => brother
# brother => nsubj => dancer
# dancer => compound => day
# dark => amod => day
# training => compound => day
# day => compound => man
# sabrina => compound => man
# passagiers => nmod => man
# de => nmod => nacht
# nacht => compound => marathon
# marathon => compound => man
# man => nsubj => thank
# in => prep => man
# bedroom => pobj => in
# thank => ROOT => thank
# smoking => compound => robocop
# robocop => advmod => thank
# insomnia => nmod => man
# iron => nmod => man
# man => nmod => shaun
# sleepy => amod => shaun
# hollow => amod => shaun
# shaun => ROOT => shaun
# dead => amod => shaun
# they => nsubj => shoot
# shoot => ROOT => shoot
# horse => dobj => shoot
# do => ROOT => do
# nt => intj => do
# they => nsubj => do
# the => det => detail
# last => amod => detail
# detail => ROOT => detail
# the => det => aviator
# aviator => compound => hour
# hour => relcl => detail
# dogville => compound => dawn
# dawn => ROOT => dawn
# dead => amod => orfanato
# el => compound => orfanato
# orfanato => nsubj => crashi
# crashi => ROOT => crashi
# all => predet => men
# president => compound => men
# men => dobj => crashi
# no => det => man
# man => nsubj => landi
# landi => ROOT => landi
# an => det => affair
# affair => nsubj => remember
# remember => ROOT => remember
# out => prt => remember
# sight => compound => madre
# todo => amod => madre
# sobre => compound => madre
# mi => compound => madre
# madre => dobj => remember
# the => det => life
# life => dobj => remember
# david => compound => angmareul
# gale => compound => angmareul
# angmareul => nsubj => boatda
# boatda => appos => life
# the => det => goldeneye
# motorcycle => compound => looper
# diary => compound => looper
# looper => nmod => babeli
# muiterij => nmod => caine
# op => compound => caine
# de => compound => caine
# caine => compound => babeli
# babeli => compound => goldeneye
# goldeneye => compound => state
# enemy => compound => state
# state => appos => life
# the => det => sunshine
# bourne => compound => sunshine
# supremacy => compound => sunshine
# sunshine => nsubj => pirate
# pirate => nsubj => caribbean
# caribbean => amod => man
# dead => amod => man
# man => nsubj => chest
# chest => ROOT => chest
# the => det => edward
# dirty => amod => dozen
# dozen => preconj => the
# sleeper => compound => shrek
# shrek => compound => edward
# edward => nsubj => scissorhands
# scissorhands => dobj => chest
# the => det => ghost
# bird => compound => ghost
# ghost => nsubj => run
# buster => compound => midnight
# midnight => appos => ghost
# run => ROOT => run
# good => amod => morning
# morning => npadvmod => run
# vietnam => compound => match
# match => nsubj => point
# point => conj => run
# un => nmod => sus
# long => amod => age
# dimanche => compound => age
# de => nmod => fiançailles
# fiançailles => compound => age
# ice => compound => age
# age => compound => sus
# el => compound => sus
# secreto => nmod => sus
# de => compound => sus
# sus => ROOT => sus
# ojos => compound => girl
# girl => nsubj => interrupted
# interrupted => ROOT => interrupted
# gravity => nmod => state
# titanic => amod => state
# easy => amod => rider
# rider => compound => state
# garden => compound => state
# state => dobj => interrupted
# they => nsubj => live
# live => ROOT => live
# fear => ccomp => live
# loathing => xcomp => fear
# la => compound => vega
# vega => dobj => loathing
# the => det => day
# evil => amod => xmen
# dead => amod => xmen
# xmen => compound => day
# day => compound => future
# future => npadvmod => live
# past => prep => future
# the => det => intouchables
# intouchables => nmod => speed
# dead => amod => duel
# calm => amod => duel
# witness => compound => duel
# duel => amod => speed
# tv => compound => movie
# movie => compound => speed
# speed => nsubj => falling
# born => acl => speed
# fourth => amod => july
# july => npadvmod => born
# falling => advcl => live
# down => prep => falling
# chicago => pobj => down
# the => det => mechanic
# mechanic => dobj => falling
# the => det => wood
# illusionist => amod => wood
# ed => compound => wood
# wood => ROOT => wood
# the => det => game
# game => nsubj => frequency
# frequency => relcl => wood
# unbreakable => amod => gangster
# american => amod => gangster
# gangster => dobj => frequency
# the => det => flower
# innocent => amod => flower
# broken => amod => flower
# flower => ROOT => flower
# ne => compound => dis
# le => compound => dis
# dis => appos => flower
# à => det => personne
# personne => nsubj => despicable
# despicable => ROOT => despicable
# me => dobj => despicable
# the => det => locker
# hurt => amod => locker
# locker => dobj => despicable
# the => det => airplane
# royal => compound => airplane
# tenenbaums => compound => airplane
# airplane => npadvmod => despicable
# mr => compound => doubtfire
# doubtfire => nsubj => tootsie
# tootsie => relcl => airplane
# the => det => pledgei
# pledgei => dobj => tootsie
# metallica => intj => pledgei
# never => neg => imagine
# los => compound => amantes
# amantes => compound => pasajeros
# pasajeros => nsubj => imagine
# imagine => conj => despicable
# you => nsubj => massacre
# the => det => massacre
# texas => compound => massacre
# chainsaw => compound => massacre
# massacre => nsubj => end
# the => det => pirate
# island => compound => pirate
# trancei => compound => drivei
# drivei => compound => pirate
# american => compound => pirate
# psycho => compound => pirate
# pirate => dobj => massacre
# caribbean => amod => world
# world => appos => pirate
# end => ccomp => imagine
# pour => compound => elle
# elle => ROOT => elle
# a => det => man
# single => amod => man
# man => nsubj => spectrei
# spectrei => ROOT => spectrei
# oblivioni => compound => perdition
# road => compound => perdition
# perdition => dobj => spectrei
# cast => acl => perdition
# away => advmod => cast
# faceoff => nmod => joy
# basic => amod => joy
# instinct => amod => joy
# joy => compound => ride
# ride => ccomp => spectrei
# sweeney => compound => street
# todd => compound => street
# demon => compound => street
# barber => compound => street
# fleet => compound => street
# street => nsubj => die
# die => ROOT => die
# hard => amod => vengeance
# vengeance => dobj => die
# zombieland => compound => number
# erin => compound => brockovich
# brockovich => compound => number
# lucky => compound => number
# number => npadvmod => slevin
# slevin => ROOT => slevin
# the => det => ultimatum
# bourne => compound => ultimatum
# ultimatum => dobj => slevin
# boogie => compound => night
# night => compound => sky
# tzameti => compound => sky
# cliffhanger => compound => booth
# phone => compound => booth
# booth => compound => sky
# miami => compound => sky
# vice => compound => sky
# hard => amod => candy
# candy => compound => sky
# iron => compound => sky
# sky => appos => ultimatum
# what => nsubj => lie
# lie => csubj => saw
# beneath => prep => lie
# gang => compound => york
# new => compound => york
# york => pobj => beneath
# any => npadvmod => lie
# given => prep => any
# sunday => pobj => given
# the => det => insidiousi
# accused => amod => insidiousi
# da => compound => insidiousi
# experiment => compound => insidiousi
# insidiousi => nsubj => saw
# saw => ROOT => saw
# snatch => compound => nebraska
# nebraska => nmod => maria
# maria => nmod => grace
# full => amod => grace
# grace => dobj => saw
# the => det => network
# social => amod => network
# network => compound => spiderman
# spiderman => ROOT => spiderman
# mariejo => compound => s
# et => compound => s
# s => nummod => spiderman
# amour => compound => memoir
# memoir => compound => geisha
# geisha => compound => hellboy
# hellboy => nsubj => scream
# scream => ROOT => scream
# xmen => dobj => scream
# the => det => man
# score => compound => man
# man => nsubj => fire
# fire => ROOT => fire
# the => det => skin
# amazing => amod => skin
# spiderman => compound => skin
# d => compound => skin
# mysterious => amod => skin
# skin => dobj => fire
# the => det => hill
# hangover => compound => hill
# valkyrie => compound => hill
# beverly => compound => hill
# hill => compound => session
# cop => compound => vera
# vera => compound => drake
# drake => compound => session
# session => ROOT => session
# the => det => conjuring
# conjuring => ROOT => conjuring
# a => det => nation
# below => amod => nation
# mission => nmod => nation
# impossible => amod => nation
# rogue => amod => nation
# nation => dobj => conjuring
# the => det => vu
# hour => compound => vu
# breakdowni => compound => godzilla
# godzilla => compound => vu
# deja => compound => vu
# vu => appos => nation
# when => advmod => met
# harry => nsubj => met
# met => advcl => conjuring
# sally => advmod => met
# the => det => phillips
# good => amod => shepherd
# shepherd => compound => holmes
# sherlock => compound => holmes
# holmes => compound => captain
# captain => compound => phillips
# phillips => npadvmod => met
# i => nsubj => legend
# legend => relcl => phillips
# last => amod => action
# action => compound => hero
# hero => nsubj => get
# get => ROOT => get
# carter => dobj => get
# the => det => mission
# artisti => compound => fracture
# fracture => compound => kong
# sinisteri => compound => king
# king => compound => kong
# kong => compound => mission
# mission => nsubj => impossible
# impossible => ROOT => impossible
# a => det => walk
# walk => dobj => impossible
# among => prep => walk
# tombstone => compound => plan
# escape => compound => plan
# plan => pobj => among
# eat => ROOT => eat
# pray => dobj => eat
# love => nmod => attraction
# fatal => amod => attraction
# attraction => compound => alceste
# alceste => dobj => pray
# à => poss => soldier
# bicyclette => compound => soldier
# tinker => compound => soldier
# tailor => compound => soldier
# soldier => dobj => alceste
# spy => nmod => mission
# mission => appos => soldier
# impossible => amod => protocol
# ghost => compound => protocol
# protocol => appos => soldier
# sleeping => compound => nonstop
# enemy => compound => salt
# salt => compound => nonstop
# nonstop => nsubj => taken
# taken => ROOT => taken
# pirate => compound => tide
# caribbean => amod => tide
# stranger => amod => tide
# tide => dobj => taken
# the => det => spy
# spy => nsubj => loved
# loved => ROOT => loved
# me => dobj => loved
# from => prep => loved
# russia => pobj => from
# love => nmod => diamond
# cube => compound => home
# home => nmod => diamond
# alone => advmod => home
# diamond => ROOT => diamond
# forever => advmod => die
# the => det => weapon
# hand => compound => weapon
# rock => compound => cradle
# cradle => compound => weapon
# prometheusi => compound => weapon
# lethal => compound => weapon
# weapon => nsubj => die
# die => ROOT => die
# hard => advmod => die
# the => det => closeri
# crazy => amod => closeri
# exam => compound => closeri
# closeri => compound => tillsammans
# tillsammans => compound => mia
# mamma => compound => mia
# mia => ROOT => mia
# nan => compound => haute
# haute => compound => destination
# tension => nmod => destination
# final => amod => destination
# destination => ROOT => destination
# i => nsubj => know
# know => ROOT => know
# last => amod => summer
# summer => npadvmod => irene
# me => nsubj => irene
# irene => ROOT => irene
# the => det => fear
# darjeeling => amod => fear
# limited => amod => fear
# fear => dobj => irene
# planet => compound => terror
# terror => ROOT => terror
# the => det => descent
# descent => dobj => terror

# %%
#Named Entity Recognition
import pandas as pd
#df = pd.read_csv('abst1.csv')
import spacy
import nltk
from spacy import displacy
import en_core_web_sm
nlp = en_core_web_sm.load()
V=[]
for i in df['cleansentence']:
  for b in nlp(i).ents:
    V.append((b.text,b.label_))
    print([b.text,b.label_])  #extracted entities
#nltk.FreqDist(label for (label,text) in V)
# Out:
# ['one', 'CARDINAL']
# ['indiana', 'GPE']
# ['seven', 'CARDINAL']
# ['apocalypse', 'PERSON']
# ['two', 'CARDINAL']
# ['north northwest', 'PERSON']
# ['terug naar de', 'ORG']
# ['american', 'NORP']
# ['forrest gump', 'PERSON']
# ['een zwerftocht de ruimte', 'PERSON']
# ['da leben der anderen', 'PERSON']
# ['cidade de', 'PERSON']
# ['third', 'ORDINAL']
# ['magnolia', 'NORP']
# ['de hobbit de woestenij van smaug', 'PERSON']
# ['mad max fury road', 'PERSON']
# ['year', 'DATE']
# ['indiana', 'GPE']
# ['art thou', 'PERSON']
# ['lawrence arabia', 'PERSON']
# ['de verloren zoon', 'PERSON']
# ['mielensäpahoittaja', 'ORG']
# ['ben hur', 'PERSON']
# ['der untergang', 'PERSON']
# ['gran torino', 'PERSON']
# ['de maniak', 'PERSON']
# ['wie bang', 'PERSON']
# ['virginia', 'GPE']
# ['de hobbit een onverwachte', 'PERSON']
# ['avatar', 'ORG']
# ['de zomer van de witte haai', 'PERSON']
# ['being john malkovich', 'PERSON']
# ['jackie brown', 'PERSON']
# ['american', 'NORP']
# ['paris', 'GPE']
# ['first', 'ORDINAL']
# ['million dollar', 'MONEY']
# ['harry brown', 'PERSON']
# ['la cage aux folles', 'PERSON']
# ['billy elliot', 'PERSON']
# ['de hobbit de', 'PERSON']
# ['kramer v kramer', 'PERSON']
# ['transamerica', 'ORG']
# ['harry', 'PERSON']
# ['fifth', 'ORDINAL']
# ['sixth', 'ORDINAL']
# ['jurassic park', 'PERSON']
# ['army', 'ORG']
# ['kat op een heet zinken', 'PERSON']
# ['wo hu cang long', 'PERSON']
# ['gram', 'ORG']
# ['jfk', 'PERSON']
# ['la mala', 'PERSON']
# ['de jarige man die', 'PERSON']
# ['uit', 'ORG']
# ['benjamin button', 'PERSON']
# ['english', 'NORP']
# ['philadelphia', 'GPE']
# ['rio bravo', 'PERSON']
# ['le choristes', 'PERSON']
# ['two', 'CARDINAL']
# ['american', 'NORP']
# ['eastern', 'ORG']
# ['pan labyrinth', 'ORG']
# ['corpse bride', 'PERSON']
# ['moulin rouge', 'PERSON']
# ['leaving la vega', 'PERSON']
# ['lincoln', 'ORG']
# ['zero', 'CARDINAL']
# ['thirty', 'CARDINAL']
# ['donnie brasco', 'PERSON']
# ['la piel que habito', 'PERSON']
# ['le misérables', 'PERSON']
# ['donnie darko', 'PERSON']
# ['dancer dark', 'PERSON']
# ['sleepy hollow', 'PERSON']
# ['el orfanato', 'PERSON']
# ['crashi', 'ORG']
# ['sobre mi', 'PERSON']
# ['david gale', 'PERSON']
# ['angmareul boatda', 'PERSON']
# ['muiterij op de caine', 'PERSON']
# ['pirate caribbean dead', 'ORG']
# ['dozen', 'CARDINAL']
# ['edward scissorhands', 'PERSON']
# ['midnight', 'TIME']
# ['morning', 'TIME']
# ['vietnam', 'GPE']
# ['un long dimanche de', 'ORG']
# ['el secreto de sus ojos', 'ORG']
# ['xmen day', 'DATE']
# ['duel tv', 'PERSON']
# ['fourth july', 'DATE']
# ['chicago', 'GPE']
# ['ed wood', 'PERSON']
# ['american', 'NORP']
# ['ne le dis à personne', 'PERSON']
# ['los amantes', 'GPE']
# ['the texas chainsaw', 'ORG']
# ['american', 'NORP']
# ['pirate caribbean world', 'ORG']
# ['zombieland', 'ORG']
# ['erin brockovich', 'PERSON']
# ['boogie night', 'TIME']
# ['miami', 'GPE']
# ['gang new york', 'ORG']
# ['sunday', 'DATE']
# ['nebraska', 'ORG']
# ['maria full grace', 'PERSON']
# ['mariejo et s amour', 'PRODUCT']
# ['beverly hill', 'PERSON']
# ['vera drake', 'PERSON']
# ['the hour', 'TIME']
# ['harry', 'PERSON']
# ['sally', 'PERSON']
# ['phillips', 'PERSON']
# ['alceste', 'PERSON']
# ['bicyclette', 'PERSON']
# ['russia', 'GPE']
# ['last summer', 'DATE']
